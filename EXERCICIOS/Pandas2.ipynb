# %% [markdown]
# ## Overview
#
# This notebook will show you how to create and query a table or DataFrame that you uploaded to DBFS. [DBFS](https://docs.databricks.com/user-guide/dbfs-databricks-file-system.html) is a Databricks File System that allows you to store data for querying inside of Databricks. This notebook assumes that you have a file already inside of DBFS that you would like to read from.
#
# This notebook is written in **Python** so the default cell type is Python. However, you can use different languages by using the `%LANGUAGE` syntax. Python, Scala, SQL, and R are all supported.

# %%
import pandas as pd
import numpy as np

# %%
# File location and type
file_location = "/FileStore/tables/Companhia_MB-1.txt"
df = spark.read.csv(file_location, header=True, sep="\t")
df = df.toPandas()

# %%
df.head(20)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>N</th>
#       <th>estado_civil</th>
#       <th>grau_instrucao</th>
#       <th>n_filhos</th>
#       <th>salario</th>
#       <th>idade_anos</th>
#       <th>reg_procedencia</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>solteiro</td>
#       <td>1-ensino fundamental</td>
#       <td>None</td>
#       <td>4</td>
#       <td>26</td>
#       <td>interior</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>casado</td>
#       <td>1-ensino fundamental</td>
#       <td>1</td>
#       <td>4.56</td>
#       <td>32</td>
#       <td>capital</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>casado</td>
#       <td>1-ensino fundamental</td>
#       <td>2</td>
#       <td>5.25</td>
#       <td>36</td>
#       <td>capital</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>solteiro</td>
#       <td>2-ensino medio</td>
#       <td>None</td>
#       <td>5.73</td>
#       <td>20</td>
#       <td>outra</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>solteiro</td>
#       <td>1-ensino fundamental</td>
#       <td>None</td>
#       <td>6.26</td>
#       <td>40</td>
#       <td>outra</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>casado</td>
#       <td>1-ensino fundamental</td>
#       <td>0</td>
#       <td>6.66</td>
#       <td>28</td>
#       <td>interior</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td>solteiro</td>
#       <td>1-ensino fundamental</td>
#       <td>None</td>
#       <td>6.86</td>
#       <td>41</td>
#       <td>interior</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8</td>
#       <td>solteiro</td>
#       <td>1-ensino fundamental</td>
#       <td>None</td>
#       <td>7.39</td>
#       <td>43</td>
#       <td>capital</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>9</td>
#       <td>casado</td>
#       <td>2-ensino medio</td>
#       <td>1</td>
#       <td>7.59</td>
#       <td>34</td>
#       <td>capital</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>10</td>
#       <td>solteiro</td>
#       <td>2-ensino medio</td>
#       <td>None</td>
#       <td>7.44</td>
#       <td>23</td>
#       <td>outra</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>11</td>
#       <td>casado</td>
#       <td>2-ensino medio</td>
#       <td>2</td>
#       <td>8.12</td>
#       <td>33</td>
#       <td>interior</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>12</td>
#       <td>solteiro</td>
#       <td>1-ensino fundamental</td>
#       <td>None</td>
#       <td>8.46</td>
#       <td>27</td>
#       <td>capital</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>13</td>
#       <td>solteiro</td>
#       <td>2-ensino medio</td>
#       <td>None</td>
#       <td>8.74</td>
#       <td>37</td>
#       <td>outra</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>14</td>
#       <td>casado</td>
#       <td>1-ensino fundamental</td>
#       <td>3</td>
#       <td>8.95</td>
#       <td>44</td>
#       <td>outra</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>15</td>
#       <td>casado</td>
#       <td>2-ensino medio</td>
#       <td>0</td>
#       <td>9.13</td>
#       <td>30</td>
#       <td>interior</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>16</td>
#       <td>solteiro</td>
#       <td>2-ensino medio</td>
#       <td>None</td>
#       <td>9.35</td>
#       <td>38</td>
#       <td>outra</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>17</td>
#       <td>casado</td>
#       <td>2-ensino medio</td>
#       <td>1</td>
#       <td>9.77</td>
#       <td>31</td>
#       <td>capital</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>18</td>
#       <td>casado</td>
#       <td>1-ensino fundamental</td>
#       <td>2</td>
#       <td>9.8</td>
#       <td>39</td>
#       <td>outra</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>19</td>
#       <td>solteiro</td>
#       <td>3-superior</td>
#       <td>None</td>
#       <td>10.53</td>
#       <td>25</td>
#       <td>interior</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>20</td>
#       <td>solteiro</td>
#       <td>2-ensino medio</td>
#       <td>None</td>
#       <td>10.76</td>
#       <td>37</td>
#       <td>interior</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
import pandas as pd
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>N\testado_civil\tgrau_instrucao\tn_filhos\tsal...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1\tsolteiro\t1-ensino fundamental\t\t4\t26\tin...</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2\tcasado\t1-ensino fundamental\t1\t4.56\t32\t...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3\tcasado\t1-ensino fundamental\t2\t5.25\t36\t...</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4\tsolteiro\t2-ensino medio\t\t5.73\t20\toutra\r</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
import pandas as pd

pd.crosstab(['a', 'b', 'c', 'a', 'a', 'c'], [1,2,3,1,2,3])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <command-1272890611529839> in <cell line: 3>()
#       1 import pandas as pd
#       2
# ----> 3 pd.crosstab(['a', 'b', 'c', 'a', 'a', 'c'], [1,2,3,1,2,3])
#
# /databricks/python/lib/python3.9/site-packages/pandas/core/reshape/pivot.py in crosstab(index, columns, values, rownames, colnames, aggfunc, margins, margins_name, dropna, normalize)
#     652         **dict(zip(unique_colnames, columns)),
#     653     }
# --> 654     df = DataFrame(data, index=common_idx)
#     655
#     656     if values is None:
#
# /databricks/python/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# /databricks/python/lib/python3.9/site-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     462         # TODO: can we get rid of the dt64tz special case above?
#     463
# --> 464     return arrays_to_mgr(
#     465         arrays, data_names, index, columns, dtype=dtype, typ=typ, consolidate=copy
#     466     )
#
# /databricks/python/lib/python3.9/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity, typ, consolidate)
#     117         # figure out the index, if necessary
#     118         if index is None:
# --> 119             index = _extract_index(arrays)
#     120         else:
#     121             index = ensure_index(index)
#
# /databricks/python/lib/python3.9/site-packages/pandas/core/internals/construction.py in _extract_index(data)
#     623
#     624         if not indexes and not raw_lengths:
# --> 625             raise ValueError("If using all scalar values, you must pass an index")
#     626
#     627         if have_series:
#
# ValueError: If using all scalar values, you must pass an index
