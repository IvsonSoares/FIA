# %% [markdown]
# # Case de Análise de Dados no Pandas!
#
# Iremos usar o banco de dados [Online Retail.xlsx](https://archive.ics.uci.edu/ml/datasets/Online+Retail), disponível no [Repositório de Dados para Machine Learning da UCI](https://archive.ics.uci.edu/ml/index.php). Para efeitos didáticos, eu fiz uma transformação no banco de dados para incluir a coluna `region`, que contém o nome do país assim como do continente.
#
# ![title](https://raw.githubusercontent.com/amauri-ti/labdata/main/imgs/uci-logo.png)

# %% [markdown]
# ### Importando as bibliotecas necessárias e o banco de dados

# %%
import numpy as np
import pandas as pd

# %%
df = spark.read.csv("/FileStore/tables/retail.csv", header=True, sep=',')
df = df.toPandas()

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>2.55</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8</td>
#       <td>12/1/10 8:26</td>
#       <td>2.75</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536365</td>
#       <td>84029G</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536365</td>
#       <td>84029E</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
display(dbutils.fs.ls('/FileStore/tables/'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/Companhia_MB-1.txt</td><td>Companhia_MB-1.txt</td><td>1710</td><td>1682346080000</td></tr><tr><td>dbfs:/FileStore/tables/Companhia_MB-2.txt</td><td>Companhia_MB-2.txt</td><td>1710</td><td>1682347119000</td></tr><tr><td>dbfs:/FileStore/tables/Companhia_MB.txt</td><td>Companhia_MB.txt</td><td>1710</td><td>1682346058000</td></tr><tr><td>dbfs:/FileStore/tables/retail-1.csv</td><td>retail-1.csv</td><td>44496854</td><td>1682426879000</td></tr><tr><td>dbfs:/FileStore/tables/retail.csv</td><td>retail.csv</td><td>44496854</td><td>1682001425000</td></tr></tbody></table></div>

# %% [markdown]
# #### Significado das colunas:
#
# * `invoice_no`: número do pedido
# * `stock_code`: número único que caracteriza o item/produto (SKU)
# * `description`: descrição/nome do produto
# * `quantity`: quantidade do produto vendida
# * `invoice_date`: data em que o pedido foi realizado
# * `unit_price`: preço unitário
# * `customer_id`: identificador único do cliente
# * `region`: região de onde o cliente realizou a compra

# %% [markdown]
# # Operações básicas de dados no Pandas

# %% [markdown]
# ## 1. Selecionando colunas
#
# Existem 2 formas de selecionar colunas no Pandas: a primeira é usando o `parênteses` e a segunda usando o método `filter()`.

# %%
df[['stock_code', 'unit_price']]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>stock_code</th>
#       <th>unit_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>85123A</td>
#       <td>2.55</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>71053</td>
#       <td>3.39</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>84406B</td>
#       <td>2.75</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>84029G</td>
#       <td>3.39</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>84029E</td>
#       <td>3.39</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>541904</th>
#       <td>22613</td>
#       <td>0.85</td>
#     </tr>
#     <tr>
#       <th>541905</th>
#       <td>22899</td>
#       <td>2.1</td>
#     </tr>
#     <tr>
#       <th>541906</th>
#       <td>23254</td>
#       <td>4.15</td>
#     </tr>
#     <tr>
#       <th>541907</th>
#       <td>23255</td>
#       <td>4.15</td>
#     </tr>
#     <tr>
#       <th>541908</th>
#       <td>22138</td>
#       <td>4.95</td>
#     </tr>
#   </tbody>
# </table>
# <p>541909 rows × 2 columns</p>
# </div>

# %%
df.filter(['stock_code', 'unit_price'])
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>stock_code</th>
#       <th>unit_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>85123A</td>
#       <td>2.55</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>71053</td>
#       <td>3.39</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>84406B</td>
#       <td>2.75</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>84029G</td>
#       <td>3.39</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>84029E</td>
#       <td>3.39</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>541904</th>
#       <td>22613</td>
#       <td>0.85</td>
#     </tr>
#     <tr>
#       <th>541905</th>
#       <td>22899</td>
#       <td>2.1</td>
#     </tr>
#     <tr>
#       <th>541906</th>
#       <td>23254</td>
#       <td>4.15</td>
#     </tr>
#     <tr>
#       <th>541907</th>
#       <td>23255</td>
#       <td>4.15</td>
#     </tr>
#     <tr>
#       <th>541908</th>
#       <td>22138</td>
#       <td>4.95</td>
#     </tr>
#   </tbody>
# </table>
# <p>541909 rows × 2 columns</p>
# </div>

# %%
df.filter(like='id')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>17850</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>17850</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>17850</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>17850</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>17850</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>541904</th>
#       <td>12680</td>
#     </tr>
#     <tr>
#       <th>541905</th>
#       <td>12680</td>
#     </tr>
#     <tr>
#       <th>541906</th>
#       <td>12680</td>
#     </tr>
#     <tr>
#       <th>541907</th>
#       <td>12680</td>
#     </tr>
#     <tr>
#       <th>541908</th>
#       <td>12680</td>
#     </tr>
#   </tbody>
# </table>
# <p>541909 rows × 1 columns</p>
# </div>

# %%
toy_df = pd.DataFrame({'pedido_id': [1, 1, 2, 3, 3], 
                       'produto_id': [251, 985, 390, 204, 985], 
                       'descricao': ['carro', 'boneca', 'celular', 'caderno', 'boneca'], 
                       'data_compra': ['2020-03-01', '2020-03-01', '2020-03-02', '2020-03-03', '2020-03-03'], 
                       'data_entrega': ['2020-03-02', '2020-03-02', '2020-03-03', '2020-03-04', '2020-03-04'], 
                       'valor_item': [25000, 30, 2000, 15, 30], 
                       'quantidade': [1, 1, 1, 2, 3]})
toy_df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>pedido_id</th>
#       <th>produto_id</th>
#       <th>descricao</th>
#       <th>data_compra</th>
#       <th>data_entrega</th>
#       <th>valor_item</th>
#       <th>quantidade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>251</td>
#       <td>carro</td>
#       <td>2020-03-01</td>
#       <td>2020-03-02</td>
#       <td>25000</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>985</td>
#       <td>boneca</td>
#       <td>2020-03-01</td>
#       <td>2020-03-02</td>
#       <td>30</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>390</td>
#       <td>celular</td>
#       <td>2020-03-02</td>
#       <td>2020-03-03</td>
#       <td>2000</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>204</td>
#       <td>caderno</td>
#       <td>2020-03-03</td>
#       <td>2020-03-04</td>
#       <td>15</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>985</td>
#       <td>boneca</td>
#       <td>2020-03-03</td>
#       <td>2020-03-04</td>
#       <td>30</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
toy_df.shape
# Out:
# Out[257]: (5, 7)

# %%
toy_df.filter(like='data')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>data_compra</th>
#       <th>data_entrega</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2020-03-01</td>
#       <td>2020-03-02</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2020-03-01</td>
#       <td>2020-03-02</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2020-03-02</td>
#       <td>2020-03-03</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2020-03-03</td>
#       <td>2020-03-04</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2020-03-03</td>
#       <td>2020-03-04</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
toy_df.filter(like='id')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>pedido_id</th>
#       <th>produto_id</th>
#       <th>quantidade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>251</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>985</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>390</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>204</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>985</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## 2. Filtros
#
# Também existem duas formas de realizar filtros no Pandas: uma com `parênteses` e outra com o método `query()`.

# %%
df[df['invoice_no'] == '536368']
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>21</th>
#       <td>536368</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>6</td>
#       <td>12/1/10 8:34</td>
#       <td>4.25</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>536368</td>
#       <td>22913</td>
#       <td>RED COAT RACK PARIS FASHION</td>
#       <td>3</td>
#       <td>12/1/10 8:34</td>
#       <td>4.95</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>536368</td>
#       <td>22912</td>
#       <td>YELLOW COAT RACK PARIS FASHION</td>
#       <td>3</td>
#       <td>12/1/10 8:34</td>
#       <td>4.95</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>536368</td>
#       <td>22914</td>
#       <td>BLUE COAT RACK PARIS FASHION</td>
#       <td>3</td>
#       <td>12/1/10 8:34</td>
#       <td>4.95</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.query('invoice_no == "536368"')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>21</th>
#       <td>536368</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>6</td>
#       <td>12/1/10 8:34</td>
#       <td>4.25</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>536368</td>
#       <td>22913</td>
#       <td>RED COAT RACK PARIS FASHION</td>
#       <td>3</td>
#       <td>12/1/10 8:34</td>
#       <td>4.95</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>536368</td>
#       <td>22912</td>
#       <td>YELLOW COAT RACK PARIS FASHION</td>
#       <td>3</td>
#       <td>12/1/10 8:34</td>
#       <td>4.95</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>536368</td>
#       <td>22914</td>
#       <td>BLUE COAT RACK PARIS FASHION</td>
#       <td>3</td>
#       <td>12/1/10 8:34</td>
#       <td>4.95</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### Filtrando com duas condições
#
# Condição `and`

# %%
df[(df['invoice_no'] == '536368') & (df['stock_code'] == '22960')]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>21</th>
#       <td>536368</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>6</td>
#       <td>12/1/10 8:34</td>
#       <td>4.25</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.query('invoice_no == "536368" and stock_code == "22960"')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>21</th>
#       <td>536368</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>6</td>
#       <td>12/1/10 8:34</td>
#       <td>4.25</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Condição `or`

# %%
df[(df['invoice_no'] == '536368') | (df['stock_code'] == '22960')]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>21</th>
#       <td>536368</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>6</td>
#       <td>12/1/10 8:34</td>
#       <td>4.25</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>536368</td>
#       <td>22913</td>
#       <td>RED COAT RACK PARIS FASHION</td>
#       <td>3</td>
#       <td>12/1/10 8:34</td>
#       <td>4.95</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>536368</td>
#       <td>22912</td>
#       <td>YELLOW COAT RACK PARIS FASHION</td>
#       <td>3</td>
#       <td>12/1/10 8:34</td>
#       <td>4.95</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>536368</td>
#       <td>22914</td>
#       <td>BLUE COAT RACK PARIS FASHION</td>
#       <td>3</td>
#       <td>12/1/10 8:34</td>
#       <td>4.95</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>170</th>
#       <td>536385</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>6</td>
#       <td>12/1/10 9:56</td>
#       <td>4.25</td>
#       <td>17420</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>539091</th>
#       <td>581433</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>6</td>
#       <td>12/8/11 15:54</td>
#       <td>4.25</td>
#       <td>14911</td>
#       <td>EIRE</td>
#     </tr>
#     <tr>
#       <th>539731</th>
#       <td>581439</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>3</td>
#       <td>12/8/11 16:30</td>
#       <td>8.29</td>
#       <td>None</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>539954</th>
#       <td>581451</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>6</td>
#       <td>12/8/11 17:57</td>
#       <td>4.25</td>
#       <td>17144</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>541049</th>
#       <td>581492</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>2</td>
#       <td>12/9/11 10:03</td>
#       <td>8.29</td>
#       <td>None</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>541468</th>
#       <td>581498</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>5</td>
#       <td>12/9/11 10:26</td>
#       <td>8.29</td>
#       <td>None</td>
#       <td>United Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# <p>1232 rows × 8 columns</p>
# </div>

# %%
df.query('invoice_no == "536368" or stock_code == "22960"')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>21</th>
#       <td>536368</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>6</td>
#       <td>12/1/10 8:34</td>
#       <td>4.25</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>536368</td>
#       <td>22913</td>
#       <td>RED COAT RACK PARIS FASHION</td>
#       <td>3</td>
#       <td>12/1/10 8:34</td>
#       <td>4.95</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>536368</td>
#       <td>22912</td>
#       <td>YELLOW COAT RACK PARIS FASHION</td>
#       <td>3</td>
#       <td>12/1/10 8:34</td>
#       <td>4.95</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>536368</td>
#       <td>22914</td>
#       <td>BLUE COAT RACK PARIS FASHION</td>
#       <td>3</td>
#       <td>12/1/10 8:34</td>
#       <td>4.95</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>170</th>
#       <td>536385</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>6</td>
#       <td>12/1/10 9:56</td>
#       <td>4.25</td>
#       <td>17420</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>539091</th>
#       <td>581433</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>6</td>
#       <td>12/8/11 15:54</td>
#       <td>4.25</td>
#       <td>14911</td>
#       <td>EIRE</td>
#     </tr>
#     <tr>
#       <th>539731</th>
#       <td>581439</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>3</td>
#       <td>12/8/11 16:30</td>
#       <td>8.29</td>
#       <td>None</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>539954</th>
#       <td>581451</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>6</td>
#       <td>12/8/11 17:57</td>
#       <td>4.25</td>
#       <td>17144</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>541049</th>
#       <td>581492</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>2</td>
#       <td>12/9/11 10:03</td>
#       <td>8.29</td>
#       <td>None</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>541468</th>
#       <td>581498</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>5</td>
#       <td>12/9/11 10:26</td>
#       <td>8.29</td>
#       <td>None</td>
#       <td>United Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# <p>1232 rows × 8 columns</p>
# </div>

# %% [markdown]
# ## 3. Criando novas colunas
#
# Existem duas formas de criar colunas com o Pandas: uma com `parênteses` e outra usando o método `assign()`.

# %%
df['total_price'] = df['quantity'] + df['unit_price']

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#       <th>total_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>2.55</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>62.55</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>63.39</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8</td>
#       <td>12/1/10 8:26</td>
#       <td>2.75</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>82.75</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536365</td>
#       <td>84029G</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>63.39</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536365</td>
#       <td>84029E</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>63.39</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.drop('total_price', axis=1, inplace=True)

# %%
df.assign(total_price = df['quantity'] + df['unit_price']).head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#       <th>total_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>2.55</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>62.55</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>63.39</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8</td>
#       <td>12/1/10 8:26</td>
#       <td>2.75</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>82.75</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536365</td>
#       <td>84029G</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>63.39</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536365</td>
#       <td>84029E</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>63.39</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>2.55</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8</td>
#       <td>12/1/10 8:26</td>
#       <td>2.75</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536365</td>
#       <td>84029G</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536365</td>
#       <td>84029E</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# O método `assign()` não modifica a tabela inplace. O que o torna uma boa opção para validar a nova coluna criada antes de efetivamente adicioná-la na tabela.

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>2.55</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8</td>
#       <td>12/1/10 8:26</td>
#       <td>2.75</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536365</td>
#       <td>84029G</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536365</td>
#       <td>84029E</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Para salvar a coluna de fato, devemos atribuir a operação para uma tabela.

# %%
df = df.assign(total_price = df['quantity'] + df['unit_price'])

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#       <th>total_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>2.55</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>62.55</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>63.39</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8</td>
#       <td>12/1/10 8:26</td>
#       <td>2.75</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>82.75</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536365</td>
#       <td>84029G</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>63.39</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536365</td>
#       <td>84029E</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>63.39</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.drop('total_price', axis=1, inplace=True)

# %% [markdown]
# ## 4. Ordenando colunas
#
# Aqui, existem apenas um método: `sort_values()`.

# %%
df.sort_values('invoice_date').head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>50806</th>
#       <td>540558</td>
#       <td>21258</td>
#       <td>?</td>
#       <td>-29</td>
#       <td>1/10/11 10:04</td>
#       <td>0</td>
#       <td>None</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>50807</th>
#       <td>C540559</td>
#       <td>21888</td>
#       <td>BINGO SET</td>
#       <td>-4</td>
#       <td>1/10/11 10:07</td>
#       <td>3.75</td>
#       <td>None</td>
#       <td>EIRE</td>
#     </tr>
#     <tr>
#       <th>50808</th>
#       <td>540560</td>
#       <td>21589</td>
#       <td>None</td>
#       <td>-14</td>
#       <td>1/10/11 10:08</td>
#       <td>0</td>
#       <td>None</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>50828</th>
#       <td>540561</td>
#       <td>21385</td>
#       <td>IVORY HANGING DECORATION  HEART</td>
#       <td>24</td>
#       <td>1/10/11 10:32</td>
#       <td>0.85</td>
#       <td>13004</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>50815</th>
#       <td>540561</td>
#       <td>21232</td>
#       <td>STRAWBERRY CERAMIC TRINKET BOX</td>
#       <td>12</td>
#       <td>1/10/11 10:32</td>
#       <td>1.25</td>
#       <td>13004</td>
#       <td>United Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.sort_values('invoice_date', ascending=False).head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>332571</th>
#       <td>566079</td>
#       <td>22923</td>
#       <td>FRIDGE MAGNETS LES ENFANTS ASSORTED</td>
#       <td>24</td>
#       <td>9/9/11 9:52</td>
#       <td>0.85</td>
#       <td>17593</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>332544</th>
#       <td>566079</td>
#       <td>23403</td>
#       <td>LETTER HOLDER HOME SWEET HOME</td>
#       <td>4</td>
#       <td>9/9/11 9:52</td>
#       <td>3.75</td>
#       <td>17593</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>332551</th>
#       <td>566079</td>
#       <td>22396</td>
#       <td>MAGNETS PACK OF 4 RETRO PHOTO</td>
#       <td>24</td>
#       <td>9/9/11 9:52</td>
#       <td>0.39</td>
#       <td>17593</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>332550</th>
#       <td>566079</td>
#       <td>22400</td>
#       <td>MAGNETS PACK OF 4 HOME SWEET HOME</td>
#       <td>24</td>
#       <td>9/9/11 9:52</td>
#       <td>0.39</td>
#       <td>17593</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>332549</th>
#       <td>566079</td>
#       <td>20838</td>
#       <td>FRENCH LATTICE CUSHION COVER</td>
#       <td>12</td>
#       <td>9/9/11 9:52</td>
#       <td>0.85</td>
#       <td>17593</td>
#       <td>United Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## 5. Aggregações
#
# No Pandas podemos criar agregações de duas formas: em uma coluna ou em grupos.
#
# ### Agregações em uma coluna

# %%
df['invoice_date'].min()
# Out:
# Out[277]: '1/10/11 10:04'

# %%
df['invoice_date'].max()
# Out:
# Out[278]: '9/9/11 9:52'

# %%
df.agg({'invoice_date': ['min', 'max']})
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>min</th>
#       <td>1/10/11 10:04</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>9/9/11 9:52</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### Agregações no método `groupby()`

# %%
df.groupby('invoice_no').agg(n=('stock_code', 'count')).reset_index()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>n</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536366</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536367</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536368</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536369</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>25895</th>
#       <td>C581484</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>25896</th>
#       <td>C581490</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>25897</th>
#       <td>C581499</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>25898</th>
#       <td>C581568</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>25899</th>
#       <td>C581569</td>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table>
# <p>25900 rows × 2 columns</p>
# </div>

# %% [markdown]
# ## 6. Combinando as operações

# %% [markdown]
# Limpando os nossos dados. Pedidos com começam com a letra `C` foram cancelados, logo devem ser retirados da base de dados.
# Também temos pedidos com quantidades negativas, que significa que ou foram cancelados ou estornados.

# %%
#df = (
#    df
#    .assign(start_with_c = lambda x: x['invoice_no'].str.startswith('C'))
#    .query('start_with_c == False')
#    .query('quantity >= 0')
#)

# %% [markdown]
# ##### Realize uma 'query' que retorne os top 10 pedidos com mais itens.

# %%
df.groupby('invoice_no').agg(n=('stock_code', 'count')).reset_index().sort_values('n', ascending=False).head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>n</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>18141</th>
#       <td>573585</td>
#       <td>1114</td>
#     </tr>
#     <tr>
#       <th>21897</th>
#       <td>581219</td>
#       <td>749</td>
#     </tr>
#     <tr>
#       <th>22032</th>
#       <td>581492</td>
#       <td>731</td>
#     </tr>
#     <tr>
#       <th>21645</th>
#       <td>580729</td>
#       <td>721</td>
#     </tr>
#     <tr>
#       <th>10713</th>
#       <td>558475</td>
#       <td>705</td>
#     </tr>
#     <tr>
#       <th>21164</th>
#       <td>579777</td>
#       <td>687</td>
#     </tr>
#     <tr>
#       <th>21895</th>
#       <td>581217</td>
#       <td>676</td>
#     </tr>
#     <tr>
#       <th>576</th>
#       <td>537434</td>
#       <td>675</td>
#     </tr>
#     <tr>
#       <th>21646</th>
#       <td>580730</td>
#       <td>662</td>
#     </tr>
#     <tr>
#       <th>881</th>
#       <td>538071</td>
#       <td>652</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Traga a data em que o pedido foi realizado

# %%
(
    df
    .groupby('invoice_no')
    .agg(n        = ('stock_code', 'count'), 
         datetime = ('invoice_date', 'first'))
    .reset_index()
    .sort_values('n', ascending=False)
    .head(10)
)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>n</th>
#       <th>datetime</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>18141</th>
#       <td>573585</td>
#       <td>1114</td>
#       <td>10/31/11 14:41</td>
#     </tr>
#     <tr>
#       <th>21897</th>
#       <td>581219</td>
#       <td>749</td>
#       <td>12/8/11 9:28</td>
#     </tr>
#     <tr>
#       <th>22032</th>
#       <td>581492</td>
#       <td>731</td>
#       <td>12/9/11 10:03</td>
#     </tr>
#     <tr>
#       <th>21645</th>
#       <td>580729</td>
#       <td>721</td>
#       <td>12/5/11 17:24</td>
#     </tr>
#     <tr>
#       <th>10713</th>
#       <td>558475</td>
#       <td>705</td>
#       <td>6/29/11 15:58</td>
#     </tr>
#     <tr>
#       <th>21164</th>
#       <td>579777</td>
#       <td>687</td>
#       <td>11/30/11 15:13</td>
#     </tr>
#     <tr>
#       <th>21895</th>
#       <td>581217</td>
#       <td>676</td>
#       <td>12/8/11 9:20</td>
#     </tr>
#     <tr>
#       <th>576</th>
#       <td>537434</td>
#       <td>675</td>
#       <td>12/6/10 16:57</td>
#     </tr>
#     <tr>
#       <th>21646</th>
#       <td>580730</td>
#       <td>662</td>
#       <td>12/5/11 17:28</td>
#     </tr>
#     <tr>
#       <th>881</th>
#       <td>538071</td>
#       <td>652</td>
#       <td>12/9/10 14:09</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Crie uma coluna apenas com a data --> valendo 1 ponto
# ### -> retornamos segunda

# %%
#import datetime as dt
from datetime import date

# %%
(
    df
    .groupby('invoice_no')
    .agg(n        = ('stock_code', 'count'), 
         datetime = ('invoice_date', 'first'))
    .reset_index()
    .sort_values('n', ascending=False)
    .head(10)
    .assign(date = date.today())
    .assign(date2 = date.today())
    .assign(date3 = date(2023, 4, 24))
)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>n</th>
#       <th>datetime</th>
#       <th>date</th>
#       <th>date2</th>
#       <th>date3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>18141</th>
#       <td>573585</td>
#       <td>1114</td>
#       <td>10/31/11 14:41</td>
#       <td>2023-04-27</td>
#       <td>2023-04-27</td>
#       <td>2023-04-24</td>
#     </tr>
#     <tr>
#       <th>21897</th>
#       <td>581219</td>
#       <td>749</td>
#       <td>12/8/11 9:28</td>
#       <td>2023-04-27</td>
#       <td>2023-04-27</td>
#       <td>2023-04-24</td>
#     </tr>
#     <tr>
#       <th>22032</th>
#       <td>581492</td>
#       <td>731</td>
#       <td>12/9/11 10:03</td>
#       <td>2023-04-27</td>
#       <td>2023-04-27</td>
#       <td>2023-04-24</td>
#     </tr>
#     <tr>
#       <th>21645</th>
#       <td>580729</td>
#       <td>721</td>
#       <td>12/5/11 17:24</td>
#       <td>2023-04-27</td>
#       <td>2023-04-27</td>
#       <td>2023-04-24</td>
#     </tr>
#     <tr>
#       <th>10713</th>
#       <td>558475</td>
#       <td>705</td>
#       <td>6/29/11 15:58</td>
#       <td>2023-04-27</td>
#       <td>2023-04-27</td>
#       <td>2023-04-24</td>
#     </tr>
#     <tr>
#       <th>21164</th>
#       <td>579777</td>
#       <td>687</td>
#       <td>11/30/11 15:13</td>
#       <td>2023-04-27</td>
#       <td>2023-04-27</td>
#       <td>2023-04-24</td>
#     </tr>
#     <tr>
#       <th>21895</th>
#       <td>581217</td>
#       <td>676</td>
#       <td>12/8/11 9:20</td>
#       <td>2023-04-27</td>
#       <td>2023-04-27</td>
#       <td>2023-04-24</td>
#     </tr>
#     <tr>
#       <th>576</th>
#       <td>537434</td>
#       <td>675</td>
#       <td>12/6/10 16:57</td>
#       <td>2023-04-27</td>
#       <td>2023-04-27</td>
#       <td>2023-04-24</td>
#     </tr>
#     <tr>
#       <th>21646</th>
#       <td>580730</td>
#       <td>662</td>
#       <td>12/5/11 17:28</td>
#       <td>2023-04-27</td>
#       <td>2023-04-27</td>
#       <td>2023-04-24</td>
#     </tr>
#     <tr>
#       <th>881</th>
#       <td>538071</td>
#       <td>652</td>
#       <td>12/9/10 14:09</td>
#       <td>2023-04-27</td>
#       <td>2023-04-27</td>
#       <td>2023-04-24</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# No pandas, assim como no SQL, não conseguimos referenciar uma coluna que acabou de ser criada. Para conseguirmos fazer isso, podemos usar funções lambda!
#
# DESAFIO VALENDO 1 PONTO! CASA!

# %%
(
    df
    .groupby('invoice_no')
    .agg(n        = ('stock_code', 'count'), 
         datetime = ('invoice_date', 'first'))
    .reset_index()
    .sort_values('n', ascending=False)
    .head(10)
    .assign(date = lambda x: x['datetime'].astype(np.datetime64).dt.date)
)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>n</th>
#       <th>datetime</th>
#       <th>date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>18141</th>
#       <td>573585</td>
#       <td>1114</td>
#       <td>10/31/11 14:41</td>
#       <td>2011-10-31</td>
#     </tr>
#     <tr>
#       <th>21897</th>
#       <td>581219</td>
#       <td>749</td>
#       <td>12/8/11 9:28</td>
#       <td>2011-12-08</td>
#     </tr>
#     <tr>
#       <th>22032</th>
#       <td>581492</td>
#       <td>731</td>
#       <td>12/9/11 10:03</td>
#       <td>2011-12-09</td>
#     </tr>
#     <tr>
#       <th>21645</th>
#       <td>580729</td>
#       <td>721</td>
#       <td>12/5/11 17:24</td>
#       <td>2011-12-05</td>
#     </tr>
#     <tr>
#       <th>10713</th>
#       <td>558475</td>
#       <td>705</td>
#       <td>6/29/11 15:58</td>
#       <td>2011-06-29</td>
#     </tr>
#     <tr>
#       <th>21164</th>
#       <td>579777</td>
#       <td>687</td>
#       <td>11/30/11 15:13</td>
#       <td>2011-11-30</td>
#     </tr>
#     <tr>
#       <th>21895</th>
#       <td>581217</td>
#       <td>676</td>
#       <td>12/8/11 9:20</td>
#       <td>2011-12-08</td>
#     </tr>
#     <tr>
#       <th>576</th>
#       <td>537434</td>
#       <td>675</td>
#       <td>12/6/10 16:57</td>
#       <td>2010-12-06</td>
#     </tr>
#     <tr>
#       <th>21646</th>
#       <td>580730</td>
#       <td>662</td>
#       <td>12/5/11 17:28</td>
#       <td>2011-12-05</td>
#     </tr>
#     <tr>
#       <th>881</th>
#       <td>538071</td>
#       <td>652</td>
#       <td>12/9/10 14:09</td>
#       <td>2010-12-09</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# A coluna `datetime` não é do time datetime. Ela é do tipo `object`.

# %%
(
    df
    .groupby('invoice_no')
    .agg(n        = ('stock_code', 'count'), 
         datetime = ('invoice_date', 'first'))
    .reset_index()
    .sort_values('n', ascending=False)
    .head(10)
    .dtypes
)
# Out:
# Out[287]: invoice_no    object
# n              int64
# datetime      object
# dtype: object

# %% [markdown]
# Então, para resolvermos o problema temos que transformar o tipo da coluna para datetime e só depois conseguiremos performar a operação desejada.

# %%
(
    df
    .groupby('invoice_no')
    .agg(n        = ('stock_code', 'count'), 
         datetime = ('invoice_date', 'first'))
    .reset_index()
    .sort_values('n', ascending=False)
    .head(10)
    .assign(datetime = lambda x: pd.to_datetime(x['datetime']))
    .dtypes
)
# Out:
# Out[288]: invoice_no            object
# n                      int64
# datetime      datetime64[ns]
# dtype: object

# %%
(
    df
    .groupby('invoice_no')
    .agg(n        = ('stock_code', 'count'), 
         datetime = ('invoice_date', 'first'))
    .reset_index()
    .sort_values('n', ascending=False)
    .head(10)
    .assign(datetime = lambda x: pd.to_datetime(x['datetime']))
    .assign(date = lambda x: x['datetime'].dt.date)
)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>n</th>
#       <th>datetime</th>
#       <th>date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>18141</th>
#       <td>573585</td>
#       <td>1114</td>
#       <td>2011-10-31 14:41:00</td>
#       <td>2011-10-31</td>
#     </tr>
#     <tr>
#       <th>21897</th>
#       <td>581219</td>
#       <td>749</td>
#       <td>2011-12-08 09:28:00</td>
#       <td>2011-12-08</td>
#     </tr>
#     <tr>
#       <th>22032</th>
#       <td>581492</td>
#       <td>731</td>
#       <td>2011-12-09 10:03:00</td>
#       <td>2011-12-09</td>
#     </tr>
#     <tr>
#       <th>21645</th>
#       <td>580729</td>
#       <td>721</td>
#       <td>2011-12-05 17:24:00</td>
#       <td>2011-12-05</td>
#     </tr>
#     <tr>
#       <th>10713</th>
#       <td>558475</td>
#       <td>705</td>
#       <td>2011-06-29 15:58:00</td>
#       <td>2011-06-29</td>
#     </tr>
#     <tr>
#       <th>21164</th>
#       <td>579777</td>
#       <td>687</td>
#       <td>2011-11-30 15:13:00</td>
#       <td>2011-11-30</td>
#     </tr>
#     <tr>
#       <th>21895</th>
#       <td>581217</td>
#       <td>676</td>
#       <td>2011-12-08 09:20:00</td>
#       <td>2011-12-08</td>
#     </tr>
#     <tr>
#       <th>576</th>
#       <td>537434</td>
#       <td>675</td>
#       <td>2010-12-06 16:57:00</td>
#       <td>2010-12-06</td>
#     </tr>
#     <tr>
#       <th>21646</th>
#       <td>580730</td>
#       <td>662</td>
#       <td>2011-12-05 17:28:00</td>
#       <td>2011-12-05</td>
#     </tr>
#     <tr>
#       <th>881</th>
#       <td>538071</td>
#       <td>652</td>
#       <td>2010-12-09 14:09:00</td>
#       <td>2010-12-09</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Agora, vamos dropar a coluna `datetime`.
#
# Jeito 1:

# %%
(
    df
    .groupby('invoice_no')
    .agg(n        = ('stock_code', 'count'), 
         datetime = ('invoice_date', 'first'))
    .reset_index()
    .sort_values('n', ascending=False)
    .head(10)
    .assign(datetime = lambda x: pd.to_datetime(x['datetime']))
    .assign(date = lambda x: x['datetime'].dt.date)
    .drop('datetime', axis=1)
)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>n</th>
#       <th>date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>18141</th>
#       <td>573585</td>
#       <td>1114</td>
#       <td>2011-10-31</td>
#     </tr>
#     <tr>
#       <th>21897</th>
#       <td>581219</td>
#       <td>749</td>
#       <td>2011-12-08</td>
#     </tr>
#     <tr>
#       <th>22032</th>
#       <td>581492</td>
#       <td>731</td>
#       <td>2011-12-09</td>
#     </tr>
#     <tr>
#       <th>21645</th>
#       <td>580729</td>
#       <td>721</td>
#       <td>2011-12-05</td>
#     </tr>
#     <tr>
#       <th>10713</th>
#       <td>558475</td>
#       <td>705</td>
#       <td>2011-06-29</td>
#     </tr>
#     <tr>
#       <th>21164</th>
#       <td>579777</td>
#       <td>687</td>
#       <td>2011-11-30</td>
#     </tr>
#     <tr>
#       <th>21895</th>
#       <td>581217</td>
#       <td>676</td>
#       <td>2011-12-08</td>
#     </tr>
#     <tr>
#       <th>576</th>
#       <td>537434</td>
#       <td>675</td>
#       <td>2010-12-06</td>
#     </tr>
#     <tr>
#       <th>21646</th>
#       <td>580730</td>
#       <td>662</td>
#       <td>2011-12-05</td>
#     </tr>
#     <tr>
#       <th>881</th>
#       <td>538071</td>
#       <td>652</td>
#       <td>2010-12-09</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Jeito 2:

# %%
(
    df
    .groupby('invoice_no')
    .agg(n        = ('stock_code', 'count'), 
         datetime = ('invoice_date', 'first'))
    .reset_index()
    .sort_values('n', ascending=False)
    .head(10)
    .assign(datetime = lambda x: pd.to_datetime(x['datetime']))
    .assign(date = lambda x: x['datetime'].dt.date)
    .filter(['invoice_no', 'n', 'date'])
)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>n</th>
#       <th>date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>18141</th>
#       <td>573585</td>
#       <td>1114</td>
#       <td>2011-10-31</td>
#     </tr>
#     <tr>
#       <th>21897</th>
#       <td>581219</td>
#       <td>749</td>
#       <td>2011-12-08</td>
#     </tr>
#     <tr>
#       <th>22032</th>
#       <td>581492</td>
#       <td>731</td>
#       <td>2011-12-09</td>
#     </tr>
#     <tr>
#       <th>21645</th>
#       <td>580729</td>
#       <td>721</td>
#       <td>2011-12-05</td>
#     </tr>
#     <tr>
#       <th>10713</th>
#       <td>558475</td>
#       <td>705</td>
#       <td>2011-06-29</td>
#     </tr>
#     <tr>
#       <th>21164</th>
#       <td>579777</td>
#       <td>687</td>
#       <td>2011-11-30</td>
#     </tr>
#     <tr>
#       <th>21895</th>
#       <td>581217</td>
#       <td>676</td>
#       <td>2011-12-08</td>
#     </tr>
#     <tr>
#       <th>576</th>
#       <td>537434</td>
#       <td>675</td>
#       <td>2010-12-06</td>
#     </tr>
#     <tr>
#       <th>21646</th>
#       <td>580730</td>
#       <td>662</td>
#       <td>2011-12-05</td>
#     </tr>
#     <tr>
#       <th>881</th>
#       <td>538071</td>
#       <td>652</td>
#       <td>2010-12-09</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
top_10_invoice_df = (
    df
    .groupby('invoice_no')
    .agg(n        = ('stock_code', 'count'), 
         datetime = ('invoice_date', 'first'))
    .reset_index()
    .sort_values('n', ascending=False)
    .head(10)
    .assign(datetime = lambda x: pd.to_datetime(x['datetime']))
    .assign(date = lambda x: x['datetime'].dt.date)
    .filter(['invoice_no', 'n', 'date'])
)

# %%
top_10_invoice_df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>n</th>
#       <th>date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>18141</th>
#       <td>573585</td>
#       <td>1114</td>
#       <td>2011-10-31</td>
#     </tr>
#     <tr>
#       <th>21897</th>
#       <td>581219</td>
#       <td>749</td>
#       <td>2011-12-08</td>
#     </tr>
#     <tr>
#       <th>22032</th>
#       <td>581492</td>
#       <td>731</td>
#       <td>2011-12-09</td>
#     </tr>
#     <tr>
#       <th>21645</th>
#       <td>580729</td>
#       <td>721</td>
#       <td>2011-12-05</td>
#     </tr>
#     <tr>
#       <th>10713</th>
#       <td>558475</td>
#       <td>705</td>
#       <td>2011-06-29</td>
#     </tr>
#     <tr>
#       <th>21164</th>
#       <td>579777</td>
#       <td>687</td>
#       <td>2011-11-30</td>
#     </tr>
#     <tr>
#       <th>21895</th>
#       <td>581217</td>
#       <td>676</td>
#       <td>2011-12-08</td>
#     </tr>
#     <tr>
#       <th>576</th>
#       <td>537434</td>
#       <td>675</td>
#       <td>2010-12-06</td>
#     </tr>
#     <tr>
#       <th>21646</th>
#       <td>580730</td>
#       <td>662</td>
#       <td>2011-12-05</td>
#     </tr>
#     <tr>
#       <th>881</th>
#       <td>538071</td>
#       <td>652</td>
#       <td>2010-12-09</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### Vamos fazer um gráfico de barras

# %%
top_10_invoice_df.plot(kind='bar', x='invoice_no', y='n', rot=45);

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(data=top_10_invoice_df, x='invoice_no', y='n');

# %%
fig, ax = plt.subplots(figsize=(10, 5))

sns.barplot(data=top_10_invoice_df, x='invoice_no', y='n', ax=ax, color='green');
ax.set_ylabel('Qtde de items no pedido', fontsize=13);
ax.set_xlabel('Pedido', fontsize=13);
ax.set_title('Top 10 Pedidos com mais Items', fontsize=15);

# %%
import matplotlib.pyplot as plt

# %%
sns.set_style('darkgrid')

fig, ax = plt.subplots(figsize=(10, 5))

sns.barplot(data=top_10_invoice_df, x='invoice_no', y='n', ax=ax, color='green');
ax.set_ylabel('Qtde de items no pedido', fontsize=13);
ax.set_xlabel('Pedido', fontsize=13);
ax.set_title('Top 10 Pedidos com mais Items', fontsize=15);

# %% [markdown]
# ### Vamos fazer um boxplot do preço total do pedido
#
# valendo 0,5!

# %%
revenue_by_invoice_df = (
    df
    .assign(total_price = lambda x: x['quantity'].astype(float) * x['unit_price'].astype(float))
    .groupby('invoice_no')
    .agg(revenue = ('total_price', 'sum'))
    .reset_index()
)

# %%
fig, ax = plt.subplots(figsize=(10, 4))

sns.boxplot(data=revenue_by_invoice_df, x='revenue', ax=ax);

# %% [markdown]
# Vamos fazer o mesmo boxplot, mas para cada mês
#
# valendo 0,5!

# %%
revenue_invoice_month_df = (
    df
    .assign(invoice_date = lambda x: pd.to_datetime(x['invoice_date']))
    .assign(month = lambda x: x['invoice_date'].dt.month)
    .assign(total_price = lambda x: x['unit_price'].astype(float) * x['quantity'].astype(float))
    .filter(['invoice_no', 'month', 'total_price'])
    .groupby('invoice_no')
    .agg(month = ('month', 'first'),
         revenue = ('total_price', 'sum'))
    .reset_index()
)

# %%
fig, ax = plt.subplots(figsize=(14, 6))


sns.boxplot(data=revenue_invoice_month_df, y='revenue', x='month', ax=ax);
ax.set_xlabel('month', fontsize=15);
ax.set_ylabel('revenue', fontsize=15);

# %% [markdown]
# # Vamos calcular a receita por país

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>2.55</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8</td>
#       <td>12/1/10 8:26</td>
#       <td>2.75</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536365</td>
#       <td>84029G</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536365</td>
#       <td>84029E</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df[['country', 'continent']] = df['region'].str.split(n=1, expand=True)

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#       <th>country</th>
#       <th>continent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>2.55</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>United</td>
#       <td>Kingdom</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>United</td>
#       <td>Kingdom</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8</td>
#       <td>12/1/10 8:26</td>
#       <td>2.75</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>United</td>
#       <td>Kingdom</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536365</td>
#       <td>84029G</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>United</td>
#       <td>Kingdom</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536365</td>
#       <td>84029E</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>United</td>
#       <td>Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### Podemos criar uma função

# %%
def separate_col(data, col, into):
    df = data.copy()
    df[into] = df[col].str.split(',', expand=True)
    return df

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#       <th>country</th>
#       <th>continent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>2.55</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>United</td>
#       <td>Kingdom</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>United</td>
#       <td>Kingdom</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8</td>
#       <td>12/1/10 8:26</td>
#       <td>2.75</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>United</td>
#       <td>Kingdom</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536365</td>
#       <td>84029G</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>United</td>
#       <td>Kingdom</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536365</td>
#       <td>84029E</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>United</td>
#       <td>Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#df = df.drop(['country', 'continent'], axis=1)

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#       <th>country</th>
#       <th>continent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>2.55</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>United</td>
#       <td>Kingdom</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>United</td>
#       <td>Kingdom</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8</td>
#       <td>12/1/10 8:26</td>
#       <td>2.75</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>United</td>
#       <td>Kingdom</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536365</td>
#       <td>84029G</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>United</td>
#       <td>Kingdom</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536365</td>
#       <td>84029E</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>United</td>
#       <td>Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#separate_col(df, col='region', into=['country', 'continent'])

# %%
#df.pipe(separate_col, col='region', into=['country', 'continent'])

# %% [markdown]
# Vamos generalizar a nossa função! Vamos incluir o argumento `sep` e `keep`.

# %%
def separate_col(data, col, into, sep=', ', keep=True):
  print(col)
  print(into)
  df = data.copy()
  try: 
    df[into] = df[col].str.split(sep, expand=True)
  except:
    df[into] = df[col].str.split(n=1, expand=True)
  if keep:
    return df
  else:
    df = df.drop(col, axis=1)
    return df

# %%
df.columns
# Out:
# Out[315]: Index(['invoice_no', 'stock_code', 'description', 'quantity', 'invoice_date',
#        'unit_price', 'customer_id', 'region', 'country', 'continent'],
#       dtype='object')

# %%
df.pipe(separate_col, col='region', into=['country', 'continent'])
# Out:
# region
# ['country', 'continent']
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#       <th>country</th>
#       <th>continent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>2.55</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>United</td>
#       <td>Kingdom</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>United</td>
#       <td>Kingdom</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8</td>
#       <td>12/1/10 8:26</td>
#       <td>2.75</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>United</td>
#       <td>Kingdom</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536365</td>
#       <td>84029G</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>United</td>
#       <td>Kingdom</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536365</td>
#       <td>84029E</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>United</td>
#       <td>Kingdom</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>541904</th>
#       <td>581587</td>
#       <td>22613</td>
#       <td>PACK OF 20 SPACEBOY NAPKINS</td>
#       <td>12</td>
#       <td>12/9/11 12:50</td>
#       <td>0.85</td>
#       <td>12680</td>
#       <td>France</td>
#       <td>France</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>541905</th>
#       <td>581587</td>
#       <td>22899</td>
#       <td>CHILDREN'S APRON DOLLY GIRL</td>
#       <td>6</td>
#       <td>12/9/11 12:50</td>
#       <td>2.1</td>
#       <td>12680</td>
#       <td>France</td>
#       <td>France</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>541906</th>
#       <td>581587</td>
#       <td>23254</td>
#       <td>CHILDRENS CUTLERY DOLLY GIRL</td>
#       <td>4</td>
#       <td>12/9/11 12:50</td>
#       <td>4.15</td>
#       <td>12680</td>
#       <td>France</td>
#       <td>France</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>541907</th>
#       <td>581587</td>
#       <td>23255</td>
#       <td>CHILDRENS CUTLERY CIRCUS PARADE</td>
#       <td>4</td>
#       <td>12/9/11 12:50</td>
#       <td>4.15</td>
#       <td>12680</td>
#       <td>France</td>
#       <td>France</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>541908</th>
#       <td>581587</td>
#       <td>22138</td>
#       <td>BAKING SET 9 PIECE RETROSPOT</td>
#       <td>3</td>
#       <td>12/9/11 12:50</td>
#       <td>4.95</td>
#       <td>12680</td>
#       <td>France</td>
#       <td>France</td>
#       <td>None</td>
#     </tr>
#   </tbody>
# </table>
# <p>541909 rows × 10 columns</p>
# </div>

# %%
df.pipe(separate_col, col='region', into=['country', 'continent'], keep=False)
# Out:
# region
# ['country', 'continent']
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>country</th>
#       <th>continent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>2.55</td>
#       <td>17850</td>
#       <td>United</td>
#       <td>Kingdom</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United</td>
#       <td>Kingdom</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8</td>
#       <td>12/1/10 8:26</td>
#       <td>2.75</td>
#       <td>17850</td>
#       <td>United</td>
#       <td>Kingdom</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536365</td>
#       <td>84029G</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United</td>
#       <td>Kingdom</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536365</td>
#       <td>84029E</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United</td>
#       <td>Kingdom</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>541904</th>
#       <td>581587</td>
#       <td>22613</td>
#       <td>PACK OF 20 SPACEBOY NAPKINS</td>
#       <td>12</td>
#       <td>12/9/11 12:50</td>
#       <td>0.85</td>
#       <td>12680</td>
#       <td>France</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>541905</th>
#       <td>581587</td>
#       <td>22899</td>
#       <td>CHILDREN'S APRON DOLLY GIRL</td>
#       <td>6</td>
#       <td>12/9/11 12:50</td>
#       <td>2.1</td>
#       <td>12680</td>
#       <td>France</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>541906</th>
#       <td>581587</td>
#       <td>23254</td>
#       <td>CHILDRENS CUTLERY DOLLY GIRL</td>
#       <td>4</td>
#       <td>12/9/11 12:50</td>
#       <td>4.15</td>
#       <td>12680</td>
#       <td>France</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>541907</th>
#       <td>581587</td>
#       <td>23255</td>
#       <td>CHILDRENS CUTLERY CIRCUS PARADE</td>
#       <td>4</td>
#       <td>12/9/11 12:50</td>
#       <td>4.15</td>
#       <td>12680</td>
#       <td>France</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>541908</th>
#       <td>581587</td>
#       <td>22138</td>
#       <td>BAKING SET 9 PIECE RETROSPOT</td>
#       <td>3</td>
#       <td>12/9/11 12:50</td>
#       <td>4.95</td>
#       <td>12680</td>
#       <td>France</td>
#       <td>None</td>
#     </tr>
#   </tbody>
# </table>
# <p>541909 rows × 9 columns</p>
# </div>

# %% [markdown]
# ### Retorne os 10 países com as maiores receitas.

# %%
top10_revenue_by_country_df = (
    df
    .pipe(separate_col, col='region', into=['country', 'continent'], keep=False)
    .assign(total_price = lambda x: x['quantity'].astype(float) * x['unit_price'].astype(float))
    .groupby('country')
    .agg(revenue = ('total_price', 'sum'))
    .reset_index()
    .sort_values('revenue', ascending=False)
    .head(10)
)
# Out:
# region
# ['country', 'continent']

# %%
top10_revenue_by_country_df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>country</th>
#       <th>revenue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>35</th>
#       <td>United</td>
#       <td>8189708.644</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>Netherlands</td>
#       <td>284661.540</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>EIRE</td>
#       <td>263276.820</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Germany</td>
#       <td>221698.210</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>France</td>
#       <td>197403.900</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>Australia</td>
#       <td>137077.270</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>Switzerland</td>
#       <td>56385.350</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>Spain</td>
#       <td>54774.580</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Belgium</td>
#       <td>40910.960</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>Sweden</td>
#       <td>36595.910</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
fig, ax = plt.subplots(figsize=(8, 6))

sns.barplot(data=top10_revenue_by_country_df, y='country', x='revenue', ax=ax, color='green');
ax.set_ylabel('Country', fontsize=13);
ax.set_xlabel('Revenu', fontsize=13);
ax.set_title('Revenue by Country', fontsize=15);

# %% [markdown]
# ### Vez de vocês! Façam o mesmo, mas para os continentes!

# %% [markdown]
# ### Vamos calcular, para cada cliente, o seu RFV

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#       <th>country</th>
#       <th>continent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>2.55</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>United</td>
#       <td>Kingdom</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>United</td>
#       <td>Kingdom</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8</td>
#       <td>12/1/10 8:26</td>
#       <td>2.75</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>United</td>
#       <td>Kingdom</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536365</td>
#       <td>84029G</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>United</td>
#       <td>Kingdom</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536365</td>
#       <td>84029E</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>6</td>
#       <td>12/1/10 8:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>United</td>
#       <td>Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
from datetime import datetime, date

rfv_df = (
    df
    .assign(total_price=df['quantity'] + df['unit_price'])
    .groupby(['customer_id'])
    .agg(revenue   = ('total_price', 'sum'), 
         frequency = ('invoice_no', 'count'), 
         last_shop = ('invoice_date', 'max'))
    .reset_index()
    .assign(last_shop = lambda x: pd.to_datetime(x['last_shop'], infer_datetime_format=True))
    .assign(ref_date = datetime.strptime('2012-01-01', '%Y-%m-%d'))
    .assign(recency = lambda x: (x['ref_date'] - x['last_shop']).dt.days)
    .filter(['ref_date', 'customer_id', 'revenue', 'frequency', 'recency'])
)

# %%
rfv_df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ref_date</th>
#       <th>customer_id</th>
#       <th>revenue</th>
#       <th>frequency</th>
#       <th>recency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2012-01-01</td>
#       <td>12346</td>
#       <td>742151.04-742151.04</td>
#       <td>2</td>
#       <td>347</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2012-01-01</td>
#       <td>12347</td>
#       <td>122.144.25123.25360.65121.25121.25121.25121.25...</td>
#       <td>182</td>
#       <td>151</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2012-01-01</td>
#       <td>12348</td>
#       <td>720.55720.55240.551200.42240.551200.42720.2914...</td>
#       <td>31</td>
#       <td>97</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2012-01-01</td>
#       <td>12349</td>
#       <td>27.529.9562.9534.2562.9561.95121.6528.25121.25...</td>
#       <td>73</td>
#       <td>40</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2012-01-01</td>
#       <td>12350</td>
#       <td>122.1122.1100.85120.85240.8562.95121.65121.651...</td>
#       <td>17</td>
#       <td>332</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>4367</th>
#       <td>2012-01-01</td>
#       <td>18280</td>
#       <td>37.929.9562.5543.7543.7562.9562.9535.9534.9582.95</td>
#       <td>10</td>
#       <td>299</td>
#     </tr>
#     <tr>
#       <th>4368</th>
#       <td>2012-01-01</td>
#       <td>18281</td>
#       <td>120.42120.42120.42116.95116.95101.6562.55</td>
#       <td>7</td>
#       <td>202</td>
#     </tr>
#     <tr>
#       <th>4369</th>
#       <td>2012-01-01</td>
#       <td>18282</td>
#       <td>112.75480.2980.8362.9592.5526.75112.75-50.2921...</td>
#       <td>13</td>
#       <td>144</td>
#     </tr>
#     <tr>
#       <th>4370</th>
#       <td>2012-01-01</td>
#       <td>18283</td>
#       <td>10.8511.6511.6511.9511.2511.2511.9521.9511.951...</td>
#       <td>756</td>
#       <td>117</td>
#     </tr>
#     <tr>
#       <th>4371</th>
#       <td>2012-01-01</td>
#       <td>18287</td>
#       <td>120.85120.85120.85121.25121.25121.2548.562.556...</td>
#       <td>70</td>
#       <td>223</td>
#     </tr>
#   </tbody>
# </table>
# <p>4372 rows × 5 columns</p>
# </div>
